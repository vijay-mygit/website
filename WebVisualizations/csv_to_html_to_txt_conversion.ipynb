# %%
import pandas as pd

# %%
df = pd.read_csv("Resources/cities.csv")

# %%
df.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity  Latitude  \
# 0        0  Puerto Ayora          20      EC  1583959155        70     -0.74
# 1        1        Avarua          46      CK  1583959030        74    -21.21
# 2        2         Pevek          99      RU  1583959157        87     69.70
# 3        3       Ambanja         100      MG  1583959158        89    -13.68
# 4        4     Tocopilla           0      CL  1583959159        39    -22.09
#
#    Longitude  Max Temperature  Wind Speed
# 0     -90.35            86.00        9.17
# 1    -159.78            84.20        9.17
# 2     170.31            -9.56        6.33
# 3      48.45            78.87        2.93
# 4     -70.20            72.01       10.94

# %%
df.reset_index(drop=True, inplace=True)

# %%
file = df.to_html()

# %%
print(file)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>City_ID</th>
#       <th>City</th>
#       <th>Cloudiness</th>
#       <th>Country</th>
#       <th>Date</th>
#       <th>Humidity</th>
#       <th>Latitude</th>
#       <th>Longitude</th>
#       <th>Max Temperature</th>
#       <th>Wind Speed</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>Puerto Ayora</td>
#       <td>20</td>
#       <td>EC</td>
#       <td>1583959155</td>
#       <td>70</td>
#       <td>-0.74</td>
#       <td>-90.35</td>
#       <td>86.00</td>
#       <td>9.17</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>Avarua</td>
#       <td>46</td>
#       <td>CK</td>
#       <td>1583959030</td>
#       <td>74</td>
#       <td>-21.21</td>
#       <td>-159.78</td>
#       <td>84.20</td>
#       <td>9.17</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2</td>
# ...

# %%
text_file = open("cities.txt", "w", encoding='UTF-8')
text_file.write(file)
text_file.close()
